# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
g = nx.Graph()

# %%
g.add_edge(1,2)
g.add_edge(2,3)
g.add_edge(3,1)
g.add_edge(3,4)
g.add_node(7)

# %%
nx.draw(g)

# %%
kc = nx.karate_club_graph()
nx.draw(kc)

# %%
g = nx.erdos_renyi_graph(50, 0.1)
nx.draw(g)

# %%
nx.diameter(g)
# Out:
# 5

# %%
ws = nx.watts_strogatz_graph(50, 3, 0.2)
nx.draw(ws)
